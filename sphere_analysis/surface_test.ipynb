# %%
import pandas as pd 
import numpy as np

# %%
coords = pd.read_csv(filepath_or_buffer='../out.txt', names =['r', 'theta', 'phi'])

# %%
coords.describe()
# Out:
#                   r         theta           phi
# count  1.019900e+04  10199.000000  10199.000000
# mean   1.000000e+00      1.570796      0.015664
# std    1.598451e-08      0.579121      1.751409
# min    1.000000e+00      0.000000     -3.110177
# 25%    1.000000e+00      1.211962     -1.570796
# 50%    1.000000e+00      1.570796      0.031478
# 75%    1.000000e+00      1.929631      1.570796
# max    1.000000e+00      3.141593      3.141593

# %%
coords.hist(column='theta', bins=100)
coords.hist(column='phi', bins=100)
# Out:
# array([[<Axes: title={'center': 'phi'}>]], dtype=object)

# %%
from math import pi

print(pi/1.211962)

print(pi/1.926)
# Out:
# 2.592154418694475
# 1.6311488336395603

# %%
icocoords = pd.read_csv(filepath_or_buffer='icosphere.txt', names =['r', 'theta', 'phi'])
icocoords.describe()
# Out:
#              r         theta           phi
# count  10242.0  10242.000000  10242.000000
# mean       0.5      1.570796      0.019324
# std        0.0      0.682961      1.813103
# min        0.5      0.000000     -3.121659
# 25%        0.5      1.047198     -1.551252
# 50%        0.5      1.570796      0.000000
# 75%        0.5      2.094395      1.570796
# max        0.5      3.141593      3.141593

# %%
icocoords.hist(column='theta', bins=100)
icocoords.hist(column='phi', bins=100)
# Out:
# array([[<Axes: title={'center': 'phi'}>]], dtype=object)

# %%
icocoords.head()
# Out:
#      r     theta       phi
# 0  0.5  1.570796  2.124371
# 1  0.5  1.570796  1.017222
# 2  0.5  1.570796 -2.124371
# 3  0.5  1.570796 -1.017222
# 4  0.5  0.553574 -1.570796

# %%
for col in coords.columns:
